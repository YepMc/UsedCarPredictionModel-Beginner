# %%
import pandas as panda
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
import joblib 
#I will be using the DecisionTreeRegressor algorithm to predict the USD prices of cars based on certain data


#Importing the dataset and encoding it
df_pre= panda.read_csv('used_car_dataset.csv')
df = pd.get_dummies(df_pre, dtype=int)

# Preparing the data for the model, splitting it into input and output testing and training variables
X= df.drop(columns= ['price_usd']) # This is the dataframe which has everything BUT what we are trying to predict
y= df['price_usd'] # This has only the output
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2) #This splits it all up

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
mae = mean_absolute_error(y_test, predictions)
print(f"On average, model's prices are off by ${mae:.2f}")

print(f"So percentage error would be {mae/df['price_usd'].mean():.2f}%")
# Out:
# On average, model's prices are off by $1201.75
# So percentage error would be 0.17%

# %%
from sklearn.ensemble import RandomForestRegressor
newModel = RandomForestRegressor(n_estimators=100)
model.fit(X_train, y_train)
predictions = model.predict(X_test)
mae = mean_absolute_error(y_test, predictions)
print(f"On average, model's prices are off by ${mae:.2f}")
print(f"So percentage error would be {mae/df['price_usd'].mean():.2f}%")
# Out:
# On average, model's prices are off by $1212.90
# So percentage error would be 0.17%
